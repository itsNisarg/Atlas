# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm

# %%
country_net = nx.read_graphml("../networks/graphml/countries_network.graphml")
city_net = nx.read_graphml("../networks/graphml/cities_network.graphml")
combined_net = nx.read_graphml("../networks/graphml/combined_network.graphml")

# %% [markdown]
# ### Shortening the game

# %%
list(nx.bridges(country_net.to_undirected()))
# Out:
# [('Burkina Faso', 'Oman'), ('Paraguay', 'Yemen'), ('Vatican City', 'Yemen')]

# %%
list(nx.simple_cycles(country_net))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 list(nx.simple_cycles(country_net))
#
# File c:\Users\Ngs11\OneDrive\Desktop\Goal-2025\Atlas\venv\Lib\site-packages\networkx\algorithms\cycles.py:235, in simple_cycles(G, length_bound)
#     232     return
#     234 if directed:
# --> 235     yield from _directed_cycle_search(G, length_bound)
#     236 else:
#     237     yield from _undirected_cycle_search(G, length_bound)
#
# File c:\Users\Ngs11\OneDrive\Desktop\Goal-2025\Atlas\venv\Lib\site-packages\networkx\algorithms\cycles.py:282, in _directed_cycle_search(G, length_bound)
#     280 v = next(iter(c))
#     281 if length_bound is None:
# --> 282     yield from _johnson_cycle_search(Gc, [v])
#     283 else:
#     284     yield from _bounded_cycle_search(Gc, [v], length_bound)
#
# File c:\Users\Ngs11\OneDrive\Desktop\Goal-2025\Atlas\venv\Lib\site-packages\networkx\algorithms\cycles.py:392, in _johnson_cycle_search(G, path)
#     390     yield path[:]
#     391     closed[-1] = True
# --> 392 elif w not in blocked:
#     393     path.append(w)
#     394     closed.append(False)
#
# KeyboardInterrupt:
